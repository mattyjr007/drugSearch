# %%
#import dataset
import pandas as pd
import numpy as np
import spacy
import re
import json
from spacy.pipeline import EntityRuler
from spacy.training import Example
from spacy.util import filter_spans
from spacy.tokens import DocBin
from tqdm import tqdm

# %%
# load the dataset
df = pd.read_parquet('clean_drug_master.parquet', engine='fastparquet')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   drug_name                      999 non-null    object
#  1   medical_condition              999 non-null    object
#  2   side_effects                   999 non-null    object
#  3   generic_name                   999 non-null    object
#  4   drug_classes                   999 non-null    object
#  5   brand_names                    999 non-null    object
#  6   activity                       999 non-null    object
#  7   rx_otc                         999 non-null    object
#  8   pregnancy_category             999 non-null    object
#  9   csa                            999 non-null    object
#  10  alcohol                        999 non-null    object
#  11  related_drugs                  999 non-null    object
#  12  medical_condition_description  999 non-null    object
#  13  rating                         999 non-null    float64
# dtypes: float64(1), object(13)
# memory usage: 109.4+ KB

# %%
# convert to lower case
df.drug_name = df.drug_name.str.lower().str.strip()

# %%
# get a list of drugs in an array inlcuding drugs with multiple names
drugs = df.drug_name.str.split("/").to_list()

# %%
# get the flattened array
drugs = [[d.strip() for d in drug] for drug in drugs]

# %% [markdown]
# ## Build NER ML MODEL
# this method try to build an NER with just drug name. result are unsucessful.

# %%
#training data of all files
TRAIN_DATA = []

for d in df.drug_name.to_list():
    TRAIN_DATA.append( {"text": d, "entities": [(0, len(d), "DRUG")] })

# %%
nlp = spacy.blank("en") # load a new spacy model
doc_bin = DocBin() # create a DocBin object

# %%
for training_example in tqdm(TRAIN_DATA):
    text = training_example['text']
    labels = training_example['entities']
    doc = nlp.make_doc(text) 
    ents = []
    for start, end, label in labels:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    filtered_ents = filter_spans(ents)
    doc.ents = filtered_ents 
    doc_bin.add(doc)

doc_bin.to_disk("training_data.spacy") # save the docbin objec
# Out:
# 100%|██████████| 999/999 [00:00<00:00, 3001.85it/s]

# %%
# !python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy train config.cfg --output ./ --paths.train ./training_data.spacy --paths.dev ./training_data.spacy
# Out:
# ℹ Saving to output directory: .
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# [2023-05-28 21:55:07,909] [INFO] Set up nlp object from config
# [2023-05-28 21:55:07,921] [INFO] Pipeline: ['tok2vec', 'ner']
# [2023-05-28 21:55:07,927] [INFO] Created vocabulary
# [2023-05-28 21:55:07,927] [INFO] Finished initializing nlp object
# [2023-05-28 21:55:08,563] [INFO] Initialized pipeline components: ['tok2vec', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     53.00    0.00    0.00    0.00    0.00
#   2     200         15.32    907.51  100.00  100.00  100.00    1.00
#   5     400          0.18      0.17  100.00  100.00  100.00    1.00
#   8     600          0.00      0.00  100.00  100.00  100.00    1.00
#  12     800          0.00      0.00  100.00  100.00  100.00    1.00
#  18    1000          0.00      0.00  100.00  100.00  100.00    1.00
#  24    1200          0.00      0.00  100.00  100.00  100.00    1.00
#  32    1400          0.41      0.27  100.00  100.00  100.00    1.00
#  41    1600          0.00      0.00  100.00  100.00  100.00    1.00
#  53    1800          0.00      0.00  100.00  100.00  100.00    1.00
# ✔ Saved pipeline to output directory
# model-last

# %%
nlp_ner = spacy.load("model-best")

# %%
text = "what are the side effects of minocycline and accutane having"
doc = nlp_ner(text)
for ent in doc.ents:
    if ent.label_ == "DRUG":
        print(ent.text, ent.label_)
# Out:
# minocycline and accutane having DRUG

# %% [markdown]
# training this model with just the drug name will not be effective and result in wrong drug detection in a drug. best resolution i to use a pattern matcher using spacy **Entity ruler** and adding it to the pipeline

# %% [markdown]
# ## Build RULE BASED NER MODEL

# %%
# Load the base English model
nlp = spacy.load("en_core_web_sm",disable=["tagger", "lemmatizer","attribute_ruler"])

# %% [markdown]
# building pattern matching and add to nlp pipeline

# %%
patterns = []

for drug in tqdm(drugs):
    for d in drug:
        min_pattern = []
        for t_split in d.split(" "):
            for t in re.split(r'(-)',t_split):
                min_pattern.append({"LOWER": t.strip()})
        patterns.append({"label": "DRUG", "pattern": min_pattern})

ruler = nlp.add_pipe("entity_ruler",before='ner')
ruler.add_patterns(patterns)
# Out:
# 100%|██████████| 999/999 [00:00<00:00, 123467.30it/s]

# %%
patterns
# Out:
# [{'label': 'DRUG', 'pattern': [{'LOWER': 'doxycycline'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'spironolactone'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'minocycline'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'accutane'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'clindamycin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'aldactone'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tretinoin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'isotretinoin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'bactrim'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'retin'}, {'LOWER': '-'}, {'LOWER': 'a'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'aczone'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzoyl'}, {'LOWER': 'peroxide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'differin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'epiduo'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'adapalene'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'cephalexin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'doryx'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tetracycline'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'septra'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'solodyn'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tazorac'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'vibramycin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acticlate'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzoyl'}, {'LOWER': 'peroxide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'clindamycin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'doxy'}, {'LOWER': '100'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'keflex'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sulfamethoxazole'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'trimethoprim'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzaclin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'monodox'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'targadox'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'adoxa'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'adoxa'}, {'LOWER': 'ck'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'adoxa'}, {'LOWER': 'pak'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'adoxa'}, {'LOWER': 'tt'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'avidoxy'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'bactrim'}, {'LOWER': 'ds'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'cleocin'}, {'LOWER': 't'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'clindagel'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'doryx'}, {'LOWER': 'mpc'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'erythromycin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'morgidox'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'oraxyl'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'claravis'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'clinda'}, {'LOWER': '-'}, {'LOWER': 'derm'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'evoclin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'minocin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'yaz'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'adapalene'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzoyl'}, {'LOWER': 'peroxide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'clindacin'}, {'LOWER': 'etz'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'clindacin'}, {'LOWER': 'p'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'clindacin'}, {'LOWER': 'pac'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'clindareach'}, {'LOWER': 'pledget'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'clindets'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'milk'}, {'LOWER': 'of'}, {'LOWER': 'magnesia'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'septra'}, {'LOWER': 'ds'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'yasmin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ziana'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'absorica'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acanya'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'amnesteem'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'azelaic'}, {'LOWER': 'acid'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'co'}, {'LOWER': '-'}, {'LOWER': 'trimoxazole'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dapsone'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'duac'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'emcin'}, {'LOWER': 'clear'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'epiduo'}, {'LOWER': 'forte'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'erygel'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ery'}, {'LOWER': 'pads'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'myorisan'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'onexton'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': "phillips'"},
#    {'LOWER': 'milk'},
#    {'LOWER': 'of'},
#    {'LOWER': 'magnesia'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'salicylic'}, {'LOWER': 'acid'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'spotex'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'theramycin'}, {'LOWER': 'z'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'absorica'}, {'LOWER': 'ld'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'achromycin'}, {'LOWER': 'v'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acne'}, {'LOWER': 'treatment'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acnex'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'ala'}, {'LOWER': '-'}, {'LOWER': 'tet'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'amzeeq'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'atralin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'avita'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'azelex'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzamycin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzoyl'}, {'LOWER': 'peroxide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'erythromycin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzoyl'}, {'LOWER': 'peroxide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sulfur'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'beyaz'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'brodspec'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'cleeravue'}, {'LOWER': '-'}, {'LOWER': 'm'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'clindamycin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tretinoin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'drospirenone'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ethinyl'}, {'LOWER': 'estradiol'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dynacin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'estarylla'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ethinyl'}, {'LOWER': 'estradiol'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'norgestimate'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'gianvi'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'loryna'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'magnesium'}, {'LOWER': 'hydroxide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'minocycline'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'minolira'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ocella'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'panoxyl'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'panoxyl'},
#    {'LOWER': '10%'},
#    {'LOWER': 'acne'},
#    {'LOWER': 'foaming'},
#    {'LOWER': 'wash'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'seysara'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sotret'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'sulfacetamide'}, {'LOWER': 'sodium'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sulfur'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tazarotene'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'tri'}, {'LOWER': '-'}, {'LOWER': 'previfem'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'tri'}, {'LOWER': '-'}, {'LOWER': 'sprintec'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'veltin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ximino'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'zenatane'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acetoxyl'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'acne'}, {'LOWER': '-'}, {'LOWER': '10'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'acne'}, {'LOWER': '-'}, {'LOWER': 'clear'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acnevir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acnomel'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'acnomel'}, {'LOWER': 'acne'}, {'LOWER': 'mask'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'acnomel'}, {'LOWER': 'bp'}, {'LOWER': '5'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'aklief'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'aktipak'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'akurza'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'aliclen'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'alquam'},
#    {'LOWER': '-'},
#    {'LOWER': 'x'},
#    {'LOWER': 'acne'},
#    {'LOWER': 'therapy'},
#    {'LOWER': 'gel'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'altabax'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'altreno'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'arazlo'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'avar'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'avar'}, {'LOWER': '-'}, {'LOWER': 'e'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'avar'},
#    {'LOWER': '-'},
#    {'LOWER': 'e'},
#    {'LOWER': 'green'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'avar'},
#    {'LOWER': '-'},
#    {'LOWER': 'e'},
#    {'LOWER': 'ls'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'avar'}, {'LOWER': 'cleanser'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'avar'}, {'LOWER': 'ls'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'avar'}, {'LOWER': 'ls'}, {'LOWER': 'cleanser'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzac'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzac'}, {'LOWER': 'ac'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'benzac'}, {'LOWER': 'ac'}, {'LOWER': 'wash'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzac'}, {'LOWER': 'w'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzagel'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzagel'}, {'LOWER': 'wash'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzamycin'}, {'LOWER': 'pak'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzashave'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzefoam'}, {'LOWER': 'ultra'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzepro'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benziq'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzoyl'}, {'LOWER': 'peroxide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'hydrocortisone'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzoyl'}, {'LOWER': 'peroxide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'salicylic'}, {'LOWER': 'acid'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benzoyl'}, {'LOWER': 'peroxide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tretinoin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'binora'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'bp'},
#    {'LOWER': '10'},
#    {'LOWER': '-'},
#    {'LOWER': 'wash'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'bpo'},
#    {'LOWER': '6'},
#    {'LOWER': 'foaming'},
#    {'LOWER': 'cloths'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'bpo'}, {'LOWER': 'gel'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'bp'}, {'LOWER': 'wash'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'brevoxyl'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'brevoxyl'},
#    {'LOWER': 'acne'},
#    {'LOWER': 'wash'},
#    {'LOWER': 'kit'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'cerave'}, {'LOWER': 'sa'}, {'LOWER': 'renewing'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'clarifoam'}, {'LOWER': 'ef'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'clascoterone'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'cleanse'}, {'LOWER': '&'}, {'LOWER': 'treat'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'cleanse'},
#    {'LOWER': '&'},
#    {'LOWER': 'treat'},
#    {'LOWER': 'plus'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'clearskin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'compound'}, {'LOWER': 'w'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dermalzone'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'dhs'},
#    {'LOWER': 'salicylic'},
#    {'LOWER': 'acid'},
#    {'LOWER': '3%'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'drospirenone'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ethinyl'}, {'LOWER': 'estradiol'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'levomefolate'}, {'LOWER': 'calcium'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'dulcolax'},
#    {'LOWER': 'milk'},
#    {'LOWER': 'of'},
#    {'LOWER': 'magnesia'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'durasal'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'enzoclear'}, {'LOWER': 'foam'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ethinyl'}, {'LOWER': 'estradiol'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'norethindrone'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'ex'},
#    {'LOWER': '-'},
#    {'LOWER': 'lax'},
#    {'LOWER': 'milk'},
#    {'LOWER': 'of'},
#    {'LOWER': 'magnesia'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'fabior'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'fostex'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'fostex'}, {'LOWER': 'medicated'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'fostex'},
#    {'LOWER': 'medicated'},
#    {'LOWER': 'cleansing'},
#    {'LOWER': 'cream'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'fostex'}, {'LOWER': 'wash'}, {'LOWER': '10%'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'hydrisalic'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'inova'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'inova'}, {'LOWER': '4'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': '1'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'inova'}, {'LOWER': '8'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': '2'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'jasmiel'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'liquimat'}, {'LOWER': 'light'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'liquimat'}, {'LOWER': 'medium'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'lo'}, {'LOWER': '-'}, {'LOWER': 'zumandimine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'meted'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'mono'}, {'LOWER': '-'}, {'LOWER': 'linyah'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'neuac'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'neutrogena'},
#    {'LOWER': 'clear'},
#    {'LOWER': 'pore'},
#    {'LOWER': 'cleanser'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'mask'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'neutrogena'},
#    {'LOWER': 'rapid'},
#    {'LOWER': 'clear'},
#    {'LOWER': 'stubborn'},
#    {'LOWER': 'acne'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'nikki'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'oscion'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'oxy'}, {'LOWER': '-'}, {'LOWER': '10'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'oxy'}, {'LOWER': 'daily'}, {'LOWER': 'wash'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'p'}, {'LOWER': '&'}, {'LOWER': 's'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'panoxyl'},
#    {'LOWER': '4%'},
#    {'LOWER': 'acne'},
#    {'LOWER': 'creamy'},
#    {'LOWER': 'wash'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'pernox'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'persa'}, {'LOWER': '-'}, {'LOWER': 'gel'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'plexion'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'propa'},
#    {'LOWER': 'ph'},
#    {'LOWER': 'acne'},
#    {'LOWER': 'med'},
#    {'LOWER': 'cleansing'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'r'}, {'LOWER': 'a'}, {'LOWER': 'acne'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'resinol'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'resorcinol'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sulfur'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'resorcinol'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'retapamulin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'riax'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'sal'},
#    {'LOWER': '-'},
#    {'LOWER': 'plant'},
#    {'LOWER': 'gel'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'salactic'}, {'LOWER': 'film'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'salex'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'salicylic'}, {'LOWER': 'acid'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sulfur'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'salvax'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sarecycline'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sastid'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'scalpicin'},
#    {'LOWER': 'scalp'},
#    {'LOWER': 'relief'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sebulex'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'soluclenz'}, {'LOWER': 'rx'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'sss'},
#    {'LOWER': '10'},
#    {'LOWER': '-'},
#    {'LOWER': '4'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'sss'},
#    {'LOWER': '10'},
#    {'LOWER': '-'},
#    {'LOWER': '5'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sss'}, {'LOWER': 'cleanser'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'stri'}, {'LOWER': '-'}, {'LOWER': 'dex'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'stridex'}, {'LOWER': 'body'}, {'LOWER': 'focus'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'stridex'},
#    {'LOWER': 'maximum'},
#    {'LOWER': 'strength'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sulfacleanse'}, {'LOWER': '8'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': '4'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sulfoam'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sulfur'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'sulpho'},
#    {'LOWER': '-'},
#    {'LOWER': 'lac'},
#    {'LOWER': 'soap'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sumadan'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sumaxin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'suphera'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'syeda'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tinamed'}, {'LOWER': 'plantar'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'tri'}, {'LOWER': '-'}, {'LOWER': 'estarylla'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'tri'}, {'LOWER': '-'}, {'LOWER': 'linyah'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'tri'},
#    {'LOWER': '-'},
#    {'LOWER': 'lo'},
#    {'LOWER': '-'},
#    {'LOWER': 'marzia'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'trifarotene'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'twyneo'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'vanoxide'}, {'LOWER': '-'}, {'LOWER': 'hc'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'winlevi'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'z'},
#    {'LOWER': '-'},
#    {'LOWER': 'clinz'},
#    {'LOWER': '10'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'zarah'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'zumandimine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'vyvanse'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'adderall'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'adderall'}, {'LOWER': 'xr'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'concerta'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lisdexamfetamine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'daytrana'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'quillivant'}, {'LOWER': 'xr'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'amantadine'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'cotempla'},
#    {'LOWER': 'xr'},
#    {'LOWER': '-'},
#    {'LOWER': 'odt'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'jornay'}, {'LOWER': 'pm'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'methylphenidate'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'quillichew'}, {'LOWER': 'er'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'azstarys'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'qelbree'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'strattera'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dexedrine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'amphetamine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dextroamphetamine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ritalin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dextroamphetamine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'bupropion'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'clonidine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'intuniv'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'desoxyn'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'guanfacine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'focalin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'atomoxetine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'focalin'}, {'LOWER': 'xr'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'amphetamine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ritalin'}, {'LOWER': 'la'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'kapvay'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'methylin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dexmethylphenidate'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'methamphetamine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'modafinil'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'metadate'}, {'LOWER': 'cd'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'methylin'}, {'LOWER': 'er'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'omega'},
#    {'LOWER': '-'},
#    {'LOWER': '3'},
#    {'LOWER': 'polyunsaturated'},
#    {'LOWER': 'fatty'},
#    {'LOWER': 'acids'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'procentra'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'selegiline'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'zenzedi'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'adhansia'}, {'LOWER': 'xr'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'aptensio'}, {'LOWER': 'xr'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'armodafinil'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'desvenlafaxine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'evekeo'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'mydayis'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'relexxii'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'adzenys'}, {'LOWER': 'er'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'adzenys'},
#    {'LOWER': 'xr'},
#    {'LOWER': '-'},
#    {'LOWER': 'odt'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'desipramine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dyanavel'}, {'LOWER': 'xr'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'evekeo'}, {'LOWER': 'odt'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'imipramine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dexmethylphenidate'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'serdexmethylphenidate'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'viloxazine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'truvada'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'biktarvy'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'triumeq'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'genvoya'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'stribild'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'atripla'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'descovy'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'norvir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'isentress'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dovato'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tivicay'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'abacavir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dolutegravir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lamivudine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'prezista'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'bictegravir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'emtricitabine'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'tenofovir'}, {'LOWER': 'alafenamide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'cobicistat'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'elvitegravir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'emtricitabine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tenofovir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'cabenuva'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dolutegravir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lamivudine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'emtricitabine'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'tenofovir'}, {'LOWER': 'alafenamide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'complera'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'reyataz'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'epzicom'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ritonavir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lamivudine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tenofovir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'viread'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dolutegravir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'kaletra'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'epivir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'intelence'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sustiva'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'abacavir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'efavirenz'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'emtricitabine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tenofovir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'emtricitabine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tenofovir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'darunavir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'efavirenz'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'odefsey'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'raltegravir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'abacavir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lamivudine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'prezcobix'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'viramune'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'combivir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ziagen'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'zidovudine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'atazanavir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'emtricitabine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'emtriva'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'edurant'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lexiva'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'nevirapine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'retrovir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'selzentry'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'juluca'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'symtuza'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'trizivir'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'epivir'}, {'LOWER': '-'}, {'LOWER': 'hbv'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'etravirine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'isentress'}, {'LOWER': 'hd'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lamivudine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tenofovir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lopinavir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ritonavir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'maraviroc'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tivicay'}, {'LOWER': 'pd'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'viramune'}, {'LOWER': 'xr'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'accesspak'},
#    {'LOWER': 'for'},
#    {'LOWER': 'hiv'},
#    {'LOWER': 'pep'},
#    {'LOWER': 'basic'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'delstrigo'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'efavirenz'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lamivudine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tenofovir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'emtricitabine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'rilpivirine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tenofovir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'evotaz'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'fuzeon'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lamivudine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'zidovudine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'pifeltro'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'viracept'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'abacavir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lamivudine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'zidovudine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'aptivus'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'cimduo'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'cobicistat'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'darunavir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'cobicistat'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'elvitegravir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'emtricitabine'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'tenofovir'}, {'LOWER': 'alafenamide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'cobicistat'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'doravirine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'elvitegravir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'enfuvirtide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ibalizumab'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'immune'},
#    {'LOWER': 'globulin'},
#    {'LOWER': 'intravenous'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'invirase'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'nelfinavir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'rilpivirine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'rukobia'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'saquinavir'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 
}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'reslizumab'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'salbutamol'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'xopenex'}, {'LOWER': 'concentrate'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'difil'},
#    {'LOWER': '-'},
#    {'LOWER': 'g'},
#    {'LOWER': 'forte'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lamictal'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'latuda'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'seroquel'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'abilify'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'topiramate'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'vraylar'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lithium'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lurasidone'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'abilify'}, {'LOWER': 'maintena'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'cariprazine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'caplyta'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lumateperone'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lybalvi'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'quetiapine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'depakote'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'seroquel'}, {'LOWER': 'xr'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'divalproex'}, {'LOWER': 'sodium'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'risperdal'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'geodon'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'sertraline'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'zyprexa'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'aripiprazole'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'depakote'}, {'LOWER': 'er'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'olanzapine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'saphris'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'citalopram'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'carbamazepine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ziprasidone'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'symbyax'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'valproic'}, {'LOWER': 'acid'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'fluoxetine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'olanzapine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lamictal'}, {'LOWER': 'odt'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'levetiracetam'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lithobid'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'zyprexa'}, {'LOWER': 'zydis'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'asenapine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'equetro'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'iloperidone'}]},
# ...
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'xpect'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'zinacef'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'avelox'}, {'LOWER': 'i.v.'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'cefaclor'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'cilastatin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'imipenem'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dycill'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dynapen'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'factive'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'primaxin'}, {'LOWER': 'iv'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'carboplatin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'leukeran'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'chlorambucil'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'fluorouracil'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'doxorubicin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'etoposide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'cyclophosphamide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'vincristine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'cosmegen'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'etopophos'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ifex'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'toposar'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'vinblastine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'hycamtin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ifosfamide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dactinomycin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'fludarabine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tepadina'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'thiotepa'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'topotecan'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'atorvastatin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'simvastatin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lipitor'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'zetia'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ezetimibe'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'crestor'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'repatha'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'alirocumab'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'evolocumab'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'praluent'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'rosuvastatin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'pravastatin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lovastatin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'zocor'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'gemfibrozil'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'vytorin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'livalo'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'niacin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'altocor'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'niaspan'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'welchol'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'altoprev'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ezetimibe'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'simvastatin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'fenofibric'}, {'LOWER': 'acid'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'slo'}, {'LOWER': '-'}, {'LOWER': 'niacin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'colesevelam'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ezallor'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'flolipid'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lopid'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'pitavastatin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'atorvastatin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ezetimibe'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'fluvastatin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lescol'}, {'LOWER': 'xl'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'mycophenolate'}, {'LOWER': 'mofetil'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'niacor'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'trilipix'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ezetimibe'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'rosuvastatin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'fibricor'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'inclisiran'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'juxtapid'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'leqvio'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lomitapide'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'lypqozet'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'roszet'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'zypitamag'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benadryl'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'diphenhydramine'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'vicks'},
#    {'LOWER': 'nyquil'},
#    {'LOWER': 'd'},
#    {'LOWER': 'cold'},
#    {'LOWER': 'and'},
#    {'LOWER': 'flu'},
#    {'LOWER': 'nighttime'},
#    {'LOWER': 'relief'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'vicks'},
#    {'LOWER': 'nyquil'},
#    {'LOWER': 'cold'},
#    {'LOWER': '&'},
#    {'LOWER': 'flu'},
#    {'LOWER': 'nighttime'},
#    {'LOWER': 'relief'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'chlorpheniramine'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'coricidin'},
#    {'LOWER': 'hbp'},
#    {'LOWER': 'cold'},
#    {'LOWER': '&'},
#    {'LOWER': 'flu'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'vicks'},
#    {'LOWER': 'dayquil'},
#    {'LOWER': 'severe'},
#    {'LOWER': 'cold'},
#    {'LOWER': '&'},
#    {'LOWER': 'flu'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'benadryl'}, {'LOWER': 'allergy'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'vicks'},
#    {'LOWER': 'dayquil'},
#    {'LOWER': 'cold'},
#    {'LOWER': '&'},
#    {'LOWER': 'flu'},
#    {'LOWER': 'relief'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'vicks'},
#    {'LOWER': 'nyquil'},
#    {'LOWER': 'severe'},
#    {'LOWER': 'cold'},
#    {'LOWER': '&'},
#    {'LOWER': 'flu'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'promethazine'}, {'LOWER': 'dm'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'tylenol'},
#    {'LOWER': 'cold'},
#    {'LOWER': '&'},
#    {'LOWER': 'flu'},
#    {'LOWER': 'severe'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'vicks'}, {'LOWER': 'vaporub'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'coricidin'},
#    {'LOWER': 'hbp'},
#    {'LOWER': 'maximum'},
#    {'LOWER': 'strength'},
#    {'LOWER': 'flu'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'theraflu'},
#    {'LOWER': 'nighttime'},
#    {'LOWER': 'severe'},
#    {'LOWER': 'cold'},
#    {'LOWER': '&'},
#    {'LOWER': 'cough'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acetaminophen'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'chlorpheniramine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'phenylephrine'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'sudafed'},
#    {'LOWER': 'pe'},
#    {'LOWER': 'cold'},
#    {'LOWER': '&'},
#    {'LOWER': 'cough'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'banophen'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'benadryl'},
#    {'LOWER': 'allergy'},
#    {'LOWER': 'plus'},
#    {'LOWER': 'cold'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'pseudoephedrine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'triprolidine'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'tussionex'}, {'LOWER': 'pennkinetic'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'chlor'}, {'LOWER': '-'}, {'LOWER': 'trimeton'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'diphedryl'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'diphen'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'complete'},
#    {'LOWER': 'allergy'},
#    {'LOWER': 'relief'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tylenol'}, {'LOWER': 'cold'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'allermax'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'bronkaid'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dicopanol'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dytuss'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'mucinex'},
#    {'LOWER': 'fast'},
#    {'LOWER': '-'},
#    {'LOWER': 'max'},
#    {'LOWER': 'night'},
#    {'LOWER': 'time'},
#    {'LOWER': 'cold'},
#    {'LOWER': '&'},
#    {'LOWER': 'flu'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'scot'},
#    {'LOWER': '-'},
#    {'LOWER': 'tussin'},
#    {'LOWER': 'allergy'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'siladryl'}, {'LOWER': 'allergy'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'sudafed'},
#    {'LOWER': 'pe'},
#    {'LOWER': 'sinus'},
#    {'LOWER': '&'},
#    {'LOWER': 'allergy'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'twilite'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'tylenol'},
#    {'LOWER': 'cold'},
#    {'LOWER': 'multi'},
#    {'LOWER': '-'},
#    {'LOWER': 'symptom'},
#    {'LOWER': 'severe'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'valu'}, {'LOWER': '-'}, {'LOWER': 'dryl'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'vanamine'}, {'LOWER': 'pd'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'virtussin'}, {'LOWER': 'dac'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'benadryl'},
#    {'LOWER': 'allergy'},
#    {'LOWER': 'plus'},
#    {'LOWER': 'sinus'},
#    {'LOWER': 'headache'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'primatene'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acetaminophen'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dextromethorphan'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'doxylamine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'pseudoephedrine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acetaminophen'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dextromethorphan'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'guaifenesin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'phenylephrine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acetaminophen'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dextromethorphan'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'phenylephrine'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'aller'}, {'LOWER': '-'}, {'LOWER': 'chlor'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'allergy'}, {'LOWER': 'relief'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'brompheniramine'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'mucinex'},
#    {'LOWER': 'fast'},
#    {'LOWER': '-'},
#    {'LOWER': 'max'},
#    {'LOWER': 'severe'},
#    {'LOWER': 'cold'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'mucinex'},
#    {'LOWER': 'fast'},
#    {'LOWER': '-'},
#    {'LOWER': 'max'},
#    {'LOWER': 'severe'},
#    {'LOWER': 'congestion'},
#    {'LOWER': '&'},
#    {'LOWER': 'cold'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'sudafed'},
#    {'LOWER': 'pe'},
#    {'LOWER': 'pressure+pain+cold'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'sudafed'},
#    {'LOWER': 'pe'},
#    {'LOWER': 'severe'},
#    {'LOWER': 'cold'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'tylenol'},
#    {'LOWER': 'cold'},
#    {'LOWER': 'max'},
#    {'LOWER': 'day'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'vicks'},
#    {'LOWER': 'nyquil'},
#    {'LOWER': 'cold'},
#    {'LOWER': '&'},
#    {'LOWER': 'flu'},
#    {'LOWER': 'nighttime'},
#    {'LOWER': 'relief'},
#    {'LOWER': '(alcohol'},
#    {'LOWER': 'free)'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'wal'}, {'LOWER': '-'}, {'LOWER': 'finate'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acetaminophen'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'chlorpheniramine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dextromethorphan'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'pseudoephedrine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acetaminophen'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'chlorpheniramine'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'actifed'},
#    {'LOWER': 'cold'},
#    {'LOWER': 'and'},
#    {'LOWER': 'allergy'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'advil'}, {'LOWER': 'allergy'}, {'LOWER': 'sinus'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'alka'},
#    {'LOWER': '-'},
#    {'LOWER': 'seltzer'},
#    {'LOWER': 'plus'},
#    {'LOWER': 'cold'},
#    {'LOWER': 'formula'},
#    {'LOWER': 'sparkling'},
#    {'LOWER': 'original'},
#    {'LOWER': 'effervescent'},
#    {'LOWER': 'tablets'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'aprodine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'aspirin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'chlorpheniramine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'phenylephrine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'c.p.m.'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'camphor'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'eucalyptus'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'menthol'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'cheratussin'}, {'LOWER': 'dac'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'chlo'}, {'LOWER': '-'}, {'LOWER': 'amine'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'chlor'}, {'LOWER': '-'}, {'LOWER': 'mal'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'chlorpheniramine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'hydrocodone'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'chlorpheniramine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'phenylephrine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'chlortan'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'codeine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'guaifenesin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'pseudoephedrine'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'coricidin'},
#    {'LOWER': 'hbp'},
#    {'LOWER': 'nighttime'},
#    {'LOWER': 'multi'},
#    {'LOWER': '-'},
#    {'LOWER': 'symptom'},
#    {'LOWER': 'cold'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dextromethorphan'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'promethazine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'diphenhydramine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'phenylephrine'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'drixoral'},
#    {'LOWER': 'cold'},
#    {'LOWER': 'and'},
#    {'LOWER': 'allergy'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'ed'}, {'LOWER': '-'}, {'LOWER': 'chlortan'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'ed'},
#    {'LOWER': 'a'},
#    {'LOWER': '-'},
#    {'LOWER': 'hist'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ed'}, {'LOWER': 'chlorped'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'ed'},
#    {'LOWER': 'chlor'},
#    {'LOWER': 'ped'},
#    {'LOWER': 'jr.'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'ephedrine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'guaifenesin'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'robitussin'},
#    {'LOWER': 'peak'},
#    {'LOWER': 'cold'},
#    {'LOWER': 'nighttime'},
#    {'LOWER': 'nasal'},
#    {'LOWER': 'relief'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'theraflu'},
#    {'LOWER': 'daytime'},
#    {'LOWER': 'severe'},
#    {'LOWER': 'cold'},
#    {'LOWER': '&'},
#    {'LOWER': 'cough'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'tussicaps'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'tylenol'},
#    {'LOWER': 'cold'},
#    {'LOWER': 'multi'},
#    {'LOWER': '-'},
#    {'LOWER': 'symptom'},
#    {'LOWER': 'nighttime'}]},
#  {'label': 'DRUG',
#   'pattern': [{'LOWER': 'a'}, {'LOWER': '-'}, {'LOWER': 'phedrin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acetaminophen'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'chlorpheniramine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dextromethorphan'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'phenylephrine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acetaminophen'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dextromethorphan'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'doxylamine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'phenylephrine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acetaminophen'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dextromethorphan'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'doxylamine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acetaminophen'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dextromethorphan'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'guaifenesin'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'pseudoephedrine'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'acetaminophen'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'dextromethorphan'}]},
#  {'label': 'DRUG', 'pattern': [{'LOWER': 'pseudoephedrine'}]},
#  ...]

# %% [markdown]
# the spacy pipeline

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'parser', 'entity_ruler', 'ner']

# %%
# save model to disk
nlp.to_disk("./drugmatcher")

# %%
nlp = spacy.load('drugmatcher/')

# %%
# make a prediction
def get_result(query : str,focus : str):
    # Process the text
    text = query
    doc = nlp(text)

    # Print the entities
    query_result = []
    for ent in doc.ents:
        if ent.label_ == 'DRUG':
            query_result.append(ent.text)


    query_result = list(set(query_result))

    result = []
    focus = [f.strip() for f in focus.split(',')]
    #focus = list(set(focus))

    custom_focus = ['drug_name', 'side_effects', 'generic_name','drug_classes', 'brand_names',
       'pregnancy_category', 'csa', 'related_drugs']

    for q in query_result:
        indexes = [index for index, sublist in enumerate(drugs) if q in sublist]

        for idx in indexes:
            try:
                json_ = df.loc[idx, focus].to_json()
            except:
                json_ = df.loc[idx, custom_focus].to_json()

            result.append(json.loads(json_))

    return result

# %%
df.columns
# Out:
# Index(['drug_name', 'medical_condition', 'side_effects', 'generic_name',
#        'drug_classes', 'brand_names', 'activity', 'rx_otc',
#        'pregnancy_category', 'csa', 'alcohol', 'related_drugs',
#        'medical_condition_description', 'rating'],
#       dtype='object')

# %%
get_result("what are the effects of bactrim ?",'drug_name,side_effects, brand_names')
# Out:
# [{'drug_name': 'bactrim',
#   'side_effects': ['stomach pain',
#    'diarrhea that is watery or bloody',
#    'yellowing of your skin or eyes',
#    'a seizure',
#    'new or unusual joint pain',
#    'swelling',
#    'dry mouth',
#    'fruity breath odor',
#    'fever',
#    'high blood potassium - nausea',
#    'weakness',
#    'loss of movement',
#    'confusion',
#    'chills',
#    'easy bruising',
#    'skin rash'],
#   'brand_names': ['Bactrim DS']}]
